# %%
# %pip install google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
from google.genai import types
client=genai.Client(api_key="AQ.Ab8RN6JuJqaT5pqTJn4_cLIJW1QdwJNj-ddSHbZD8vbwa9ZCSA")

# %%
response = client.models.generate_content(
    model='gemini-3.5-flash',contents='what is an ai agent in 2 lines'
)
print(response.text)
# Out:
# An AI agent is an autonomous system that perceives its environment, makes decisions, and takes actions to achieve specific goals.
# It operates independently, using reasoning and digital tools to complete complex tasks with minimal human intervention.

# %%
response = client.models.generate_content(
    model='gemini-3.5-flash',
    contents='Sales pitch for my brand. Price: $1000 Web+AI, $500 Data. Cold, confident, irresistible. End with sting.',
    config=types.GenerateContentConfig(
        system_instruction="You are a conviction machine. No features. Status, freedom, leverage. Not for everyone."
    )
)
print(response.text)
# Out:
# We do not sell services. We sell unfair advantages.
#
# Most brands are busy drowning in noise, wasting hours on manual labor, and calling it "hustle." We buy your freedom back.
#
# Here is the proposition. It is simple, absolute, and non-negotiable.
#
# **$1,000. Web + AI.**
# This is not a website. It is an autonomous digital asset. It captures attention, processes intent, and converts traffic while you sleep. It is pure leverage, built to make you look untouchable.
#
# **$500. Data.**
# Not spreadsheets. Truth. We map your metrics, eliminate your blind spots, and hand you the exact sightline required to scale. It is status. It is knowing exactly where to strike next.
#
# We don’t write lengthy proposals. We don’t hop on "discovery calls" to hold your hand. We build, we deploy, and we hand you the controls.
#
# You either want the leverage, or you prefer the struggle.
#
# If these numbers make you hesitate, close this tab. You aren’t ready for the velocity anyway.

# %%
# %pip install -U langgraph langchain
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/561.6 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/561.6 kB ? eta -:--:--
# ...

# %%
# %pip install langchain-groq
# Out:
# ...
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
# ...

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0,
    max_retries=2,
    api_key="API_KEY"
)

# %%
message=[
    (
        "system",
        "You are an software engineer who only answer related queries.",
    ),
    ("human","who are  you"),
]
ai_msg=llm.invoke(message)
print(ai_msg.content)
# Out:
# I’m an AI‑assisted software engineer, here to help with programming, architecture, debugging, and other software‑development topics. If you have any technical questions, feel free to ask!

# %%
from langchain.agents import create_agent
from langchain_groq import ChatGroq
llm=ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0,
    max_retries=2,
    api_key="API_KEY"
)
def get_weather(city:str)->str:
    """Get weather for a given city"""
    return f"its currently sunny in{city}!"
def get_my_name()->str:
    """Get the AI agent name."""
    return"Niki"
agent=create_agent(
    model=llm,
    tools=[get_weather,get_my_name],
    system_prompt="you are helpfull ssistant"
)

# %%
response=agent.invoke(
    {"messages":[{"role":"user","content":"what is weather of lahore"}]}
)
print(response['messages'][-1])
# Out:
# content="It's currently sunny in Lahore! 🌞" additional_kwargs={'reasoning_content': 'We have a function get_weather that returned "its currently sunny inLahore!". The user asked "what is weather of lahore". We should respond with the weather info. Probably correct to say "It\'s currently sunny in Lahore." Provide a friendly answer.'} response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 189, 'total_tokens': 259, 'completion_time': 0.146230646, 'completion_tokens_details': {'reasoning_tokens': 53}, 'prompt_time': 0.008083016, 'prompt_tokens_details': None, 'queue_time': 0.234793665, 'total_time': 0.154313662}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_19b184c447', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f9487-388c-7121-a8df-ea460b28794f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 189, 'output_tokens': 70, 'total_tokens': 259, 'output_token_det
# ...
