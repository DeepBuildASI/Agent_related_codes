# %%
# %pip install google-search-results
# Out:
# Requirement already satisfied: google-search-results in c:\Users\MY PC\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.2)
# Requirement already satisfied: requests in c:\Users\MY PC\AppData\Local\Programs\Python\Python314\Lib\site-packages (from google-search-results) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\MY PC\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->google-search-results) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\MY PC\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->google-search-results) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\MY PC\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->google-search-results) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\MY PC\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->google-search-results) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
SERP_API_KEY="API_KEY"

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

from langchain_groq import ChatGroq

llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0,
    max_retries=2,
    api_key="API_KEY"    
)

# %%
from serpapi import GoogleSearch


def serpapi_search(query: str):
    """Searches for a query using the SerpAPI on Google."""
    params = {
        "q": query,
        "hl": "en",
        "gl": "us",
        "api_key": "API_KEY"
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    
    # Extract top results (titles + links)
    if "organic_results" in results:
        return [
            {"title": r["title"], "link": r["link"], "snippet": r.get("snippet", "")}
            for r in results["organic_results"][:5]
        ]
    return {"error": "No results found"}

# %%
serpapi_search("what is ASI in short definition")
# Out:
# [{'title': 'What Is Artificial Superintelligence?',
#   'link': 'https://www.ibm.com/think/topics/artificial-superintelligence',
#   'snippet': 'Artificial superintelligence (ASI) is a hypothetical software-based artificial intelligence (AI) system with an intellectual scope beyond human intelligence.'},
#  {'title': 'What is Artificial Superintelligence (ASI)?',
#   'link': 'https://www.youtube.com/watch?v=PjqGbEE7EYc',
#   'snippet': 'An ASI would be an inexhaustible hyper intelligent super being with the ability to process and analyze any amounts of data.'},
#  {'title': 'What is artificial superintelligence (ASI)? | Definition from ...',
#   'link': 'https://www.techtarget.com/searchenterpriseai/definition/artificial-superintelligence-ASI',
#   'snippet': 'Artificial superintelligence (ASI) is a hypothetical software-based system with intellectual powers beyond those of humans across a comprehensive range of ...'},
#  {'title': 'What could an Artificial Superintelligence (ASI) actually do?',
#   'link': 'https://www.reddit.com/r/IsaacArthur/comments/1l8rpf5/what_could_an_artificial_superintelligence_asi/',
#   'snippet': "Leaving aside when, if ever, an ASI might be produced, it's interesting to ponder what it might actually be able to do. In particular, what areas of scientific ..."},
#  {'title': 'From AGI to ASI',
#   'link': 'https://arxiv.org/html/2606.12683v1',
#   'snippet': 'ASI (informally) It is (per definition) an agent that maximizes the Legg-Hutter score of intelligence. ASI—it is the endpoint on the continuum ...'}]
